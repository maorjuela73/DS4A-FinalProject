# %%
import sys,os
import pandas as pd
import numpy as np
import pandas_profiling

# %%
dfApple = pd.read_csv("./data/AppleStore.csv")

# %%
dfApple[dfApple["id"]==293778748]
# Out:
#     Unnamed: 0         id track_name  size_bytes currency  price  \
# 47          55  293778748    PAC-MAN   100849664      USD    0.0
#
#     rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 47            508808                99          3.0              4.5  6.3.5
#
#    cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 47          4+       Games               38                5        10
#
#     vpp_lic
# 47        1

# %%
dfApple.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
# Looking variables 
dfApple.dtypes
# Out:
# Unnamed: 0            int64
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# dtype: object

# %%
| Variable name|  Description | Values |
|--------------|--------------|------------|
| id          | Ordinal age, coded: 1 (<= 25), 2 (26-34), 3 (35-50), 4 (50+)| Int: 1-4 | 
| track_name         | Categorical sex | Char: F, M| 
| size_bytes  | Android or OS X | String: Andr, X|
| currency| Luxury or standard vehicle| String: Lx, Std|
| price | Ordinal page views on day j| Int: 1-5 |
| user_rating | Majority page type| String: Main, Prom, Serv| 
| ver| Ordinal engagement time per day | Int: 0-5|
| cont_rating| Indicator that user drove| Int: 0, 1|
|prime_genre

# %%
# Doing pandas_profiling
pandas_profiling.ProfileReport(dfApple)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
